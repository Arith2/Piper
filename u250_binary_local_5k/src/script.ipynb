# %%
for i in range(2):
    for j in range(16):
        print("CreateDict<", (16*i+j), ">(", sep='')
        print("    categorical_stream_split_16[", i, "][", j, "],", sep='')
        print("    categorical_dict_16[", i, "][", j, "],", sep='')
        print("    row_num", sep='')
        print(");", sep='')
# Out:
# CreateDict<0>(
#     categorical_stream_split_16[0][0],
#     categorical_dict_16[0][0],
#     row_num
# );
# CreateDict<1>(
#     categorical_stream_split_16[0][1],
#     categorical_dict_16[0][1],
#     row_num
# );
# CreateDict<2>(
#     categorical_stream_split_16[0][2],
#     categorical_dict_16[0][2],
#     row_num
# );
# CreateDict<3>(
#     categorical_stream_split_16[0][3],
#     categorical_dict_16[0][3],
#     row_num
# );
# CreateDict<4>(
#     categorical_stream_split_16[0][4],
#     categorical_dict_16[0][4],
#     row_num
# );
# CreateDict<5>(
#     categorical_stream_split_16[0][5],
#     categorical_dict_16[0][5],
#     row_num
# );
# CreateDict<6>(
#     categorical_stream_split_16[0][6],
#     categorical_dict_16[0][6],
#     row_num
# );
# CreateDict<7>(
#     categorical_stream_split_16[0][7],
#     categorical_dict_16[0][7],
#     row_num
# );
# CreateDict<8>(
#     categorical_stream_split_16[0][8],
#     categorical_dict_16[0][8],
#     row_num
# );
# ...
